# %%
# !pip install datasets

# %%
from datasets import load_dataset

dataset = load_dataset("jamescalam/channel-metadata")

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Video ID', 'Channel ID', 'Title', 'Time Created', 'Time Published', 'Duration', 'Description', 'Category', 'Like Count', 'Dislike Count'],
#         num_rows: 1503
#     })
# })

# %%
data_tr=load_dataset("jamescalam/channel-metadata",split='train')

# %%
import pandas as pd

# Convert to pandas DataFrame
df = pd.DataFrame(data_tr)

# Save DataFrame to CSV
df.to_csv('dataset.csv', index=False)

# %%
df.head()
# Out:
#       Video ID                Channel ID  \
# 0  Jk1YP4Y_U_0  UCv83tO5cePwHMt1952IVVHw
# 1  gXqHd6-NKBo  UCv83tO5cePwHMt1952IVVHw
# 2  yYEPNla4tlQ  UCv83tO5cePwHMt1952IVVHw
# 3  GYDFBfx8Ts8  UCv83tO5cePwHMt1952IVVHw
# 4  DgGFhQmfxHo  UCv83tO5cePwHMt1952IVVHw
#
#                                                Title             Time Created  \
# 0   Stoic Philosophy Text Generation with TensorFlow  2020-04-19 11:33:45 UTC
# 1  How to Build TensorFlow Pipelines with tf.data...  2020-11-02 08:23:38 UTC
# 2               Every New Feature in Python 3.10.0a2  2020-11-08 18:09:49 UTC
# 3  How-to Build a Transformer for Language Classi...  2020-11-19 09:57:27 UTC
# 4                How-to use the Kaggle API in Python  2020-11-22 20:19:30 UTC
#
#             Time Published      Duration  \
# 0  2020-04-19 13:52:43 UTC  1859 seconds
# 1  2020-11-02 08:57:48 UTC  1853 seconds
# 2  2020-11-10 16:44:05 UTC   883 seconds
# 3  2020-11-19 12:20:35 UTC  2299 seconds
# ...

# %%
data=df[['Title','Description','Category']]

# %%
data.head()
# Out:
#                                                Title  \
# 0   Stoic Philosophy Text Generation with TensorFlow
# 1  How to Build TensorFlow Pipelines with tf.data...
# 2               Every New Feature in Python 3.10.0a2
# 3  How-to Build a Transformer for Language Classi...
# 4                How-to use the Kaggle API in Python
#
#                                          Description        Category
# 0  Explanation of key parts to a RNN text generat...  People & Blogs
# 1  Link to updated version (without video freeze)...  People & Blogs
# 2  Every new feature in the early release alpha 2...  People & Blogs
# 3  🎁 Free NLP for Semantic Search Course:\nhttps:...  People & Blogs
# 4  Simple step-by-step tutorial covering the setu...  People & Blogs

# %%
data.loc[5,['Description','Category']]
# Out:
# Description    Easy natural language generation with Transfor...
# Category                                          People & Blogs
# Name: 5, dtype: object

# %%
data.to_csv('dataset_classification.csv', index=False)
